# %% [markdown]
# # Explore the effects of model misspecification on Oliveira et al. 2016
# Sources:
# - [Paper]()
# - [Dataset]()

# %%
import pandas as pd
import statsmodels.formula.api as smf
import os

# %% [markdown]
# # Replicate the analyses
#
# ## Dataset: Stackoverflow
#
# ## Summmary or replication attempt:
# - There is a missing value in the dataset for Russia (pr_editions).
# -

# %%
# Load StackOverflow data
df_so = pd.read_csv("data/stackoverflow.csv")

# Filter out any countries with missing data: 
# "...we consider only the countries for which data for all explanatory
# variables is available (n =51 for StackOverflow and n =45 for Superuser)."
df_so = df_so.dropna(axis='index', how='any', subset=['pr_questions', 'pr_answers', 'pr_comments', 'pr_editions', 'IDV', 'GNI', 'Internet', 'English', 'WVS'])
assert(len(df_so) == 51)

# BUG FOUND: Russian Federation data for pr_editions is missing
# Work around: Remove Russian Federation
df_so = df_so.loc[df_so["country.iso"] != "RUS"]
assert(len(df_so) == 50)
df_so["pr_editions"] = df_so["pr_editions"].astype('float')

# Show the filtered dataset
df_so
# Show the data types
# df_so.dtypes
# Out:
#    country.iso        country.name   num_u  num_contrib      gini  pr_total  \
# 0          GTM           Guatemala     215         8112  0.948123  0.665116
# 4          COL            Colombia    1224        17713  0.875322  0.658497
# 6          IDN           Indonesia    3585        35597  0.904504  0.543375
# 9          PER                Peru     534        42535  0.955490  0.640449
# 12         KOR  Korea, Republic of    1784        24887  0.929445  0.533632
# 13         SLV         El Salvador     133         2511  0.878600  0.631579
# 14         CHN               China   13401       145338  0.925213  0.511753
# 16         VNM            Viet Nam    2319        33684  0.917303  0.558862
# 18         THA            Thailand    1152        21466  0.904932  0.555556
# 21         CHL               Chile    1075        26163  0.914023  0.664186
# 22         EGY               Egypt    1965        39057  0.890082  0.650891
# 24         HKG           Hong Kong     970        50795  0.926260  0.693814
# 26         MAR             Morocco     547        11597  0.897797  0.625229
# 27         SAU        Saudi Arabia     459        10737  0.918167  0.618736
# 30         MYS            Malaysia    1554        30707  0.882092  0.663449
# 31         PRT            Portugal    2851        73884  0.876392  0.727113
# 32         SVN            Slovenia     692        36649  0.882082  0.784682
# 33         ROU             Romania    3570       154688  0.888455  0.741457
# 34         MEX              Mexico    2973        55106  0.900064  0.636394
# 37         IRQ                Iraq     145          619  0.831709  0.517241
# 42         URY             Uruguay     569        11397  0.841517  0.706503
# 43         TUR              Turkey    4506       108674  0.890074  0.642699
# 44         BRA              Brazil   10717       211485  0.895671  0.645890
# 50         JPN               Japan    2692        80179  0.924594  0.607355
# 52         IND               India   70970      2019057  0.892815  0.693871
# 53         ESP               Spain    7349       210840  0.899774  0.682950
# 54         SVK            Slovakia     861        53971  0.912895  0.747967
# 56         AUT             Austria    2518       137698  0.886187  0.781970
# 57         CZE      Czech Republic    2703       132956  0.905091  0.733629
# 58         MLT               Malta     255        20058  0.925379  0.819608
# 59         POL              Poland    6069       236258  0.872796  0.747734
# 61         EST             Estonia     621        42083  0.904419  0.771337
# 53     0.234590     0.092802  51.0  30110.0      67.6    57.18  0.54
# 54     0.315912     0.133566  52.0  17180.0      74.4    55.96 -0.43
# 56     0.350278     0.149325  55.0  48160.0      79.8    63.21  1.43
# 57     0.299667     0.117647  58.0  18130.0      73.0    57.42  0.38
# 58     0.305882     0.109804  59.0  19760.0      69.2    66.48 -0.03
# 59     0.311254     0.126380  60.0  12660.0      64.9    64.26 -0.14
# 61     0.322061     0.141707  60.0  15830.0      76.5    61.39 -1.19
# 63     0.314272     0.129521  63.0  46940.0      89.4    64.40  1.12
# 65     0.343583     0.160988  67.0  44010.0      83.0    60.89  0.44
# 66     0.359923     0.168645  68.0  82730.0      85.2    58.29  1.90
# 67     0.341113     0.124680  69.0  98860.0      94.0    64.33  2.17
# 68     0.285021     0.120319  70.0  38970.0      76.8    69.47  1.18
# 69     0.320951     0.108470  70.0  14200.0      71.7    59.43 -1.27
# 70     0.292838     0.131528  71.0  41750.0      79.6    52.69  1.13
# 71     0.334527     0.138968  71.0  56210.0      94.0    67.80  2.35
# 72     0.289402     0.115910  74.0  59770.0      90.0    69.30  1.87
# 73     0.320234     0.146667  75.0  44990.0      78.0    61.21  1.13
# 74     0.255497     0.105834  76.0  33840.0      56.8    52.80  0.60
# 75     0.348942     0.156087  79.0  30620.0      86.0    69.30  1.86
# 76     0.328407     0.134728  80.0  50970.0      83.0    65.40  1.91
# 77     0.328028     0.149710  80.0  48250.0      92.3    68.99  1.39
# 78     0.292074     0.116721  80.0  12370.0      70.0    58.55 -1.22
# 79     0.334863     0.151428  89.0  38250.0      86.8    69.20  1.68
# 80     0.333956     0.146999  90.0  59570.0      79.5    69.00  1.75
# 81     0.320000     0.132261  91.0  50120.0      77.9    68.10  1.76

# %%
# Specify the dependent and independent variables

# Dependent variables 
dvs = ["pr_questions", "pr_answers", "pr_comments", "pr_editions"]

# m1 model IVs
baseline_ivs = ["GNI", "Internet", "English"]

# Model 1 IVs (Baseline + Individualism/Collectivism)
m1_ivs = baseline_ivs + ["IDV"]

# Model 2 IVs (Baseine + Survival/Self-expression)
m2_ivs = baseline_ivs + ["WVS"]
print(m2_ivs)
# Out:
# ['GNI', 'Internet', 'English', 'WVS']

# %%
# Baseline models
# Specify the models
baseline_formulas = list()
for dv in dvs: 
    form = dv + " ~ "
    form += '+'.join(baseline_ivs)

    baseline_formulas.append(form)

# Fit the models
baseline_results = dict()
for form in baseline_formulas:
    assert(isinstance(form, str))
    baseline_model = smf.ols(form, data=df_so)
    
    baseline_results[form] = baseline_model

print("All baseline models:")
# Print summary of models
for form,model in baseline_results.items():
    print(form)
    print(model.fit().summary())
    print("\n")

print("+++++ END BASELINE +++++")
# Out:
# All baseline models:
# pr_questions ~ GNI+Internet+English
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           pr_questions   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     16.37
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           2.23e-07
# Time:                        10:32:28   Log-Likelihood:                 77.431
# No. Observations:                  50   AIC:                            -146.9
# Df Residuals:                      46   BIC:                            -139.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2178      0.059      3.722      0.001       0.100       0.336
# GNI         7.341e-09    5.1e-07      0.014      0.989   -1.02e-06    1.03e-06
# Internet       0.0005      0.000      1.064      0.293      -0.000       0.002
# English        0.0051      0.001      4.036      0.000       0.003       0.008
# ==============================================================================
# Omnibus:                        3.655   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                2.583
# Skew:                          -0.437   Prob(JB):                        0.275
# Kurtosis:                       3.690   Cond. No.                     2.65e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# pr_answers ~ GNI+Internet+English
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             pr_answers   R-squared:                       0.576
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     20.83
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           1.14e-08
# Time:                        10:32:28   Log-Likelihood:                 70.858
# No. Observations:                  50   AIC:                            -133.7
# Df Residuals:                      46   BIC:                            -126.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1754      0.067      2.628      0.012       0.041       0.310
# GNI         5.787e-07   5.82e-07      0.995      0.325   -5.92e-07    1.75e-06
# Internet       0.0009      0.001      1.584      0.120      -0.000       0.002
# English        0.0049      0.001      3.389      0.001       0.002       0.008
# ==============================================================================
# Omnibus:                       13.965   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.638
# Skew:                          -1.093   Prob(JB):                     0.000402
# Kurtosis:                       4.651   Cond. No.                     2.65e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# pr_comments ~ GNI+Internet+English
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            pr_comments   R-squared:                       0.713
# Model:                            OLS   Adj. R-squared:                  0.694
# Method:                 Least Squares   F-statistic:                     38.07
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           1.61e-12
# Time:                        10:32:28   Log-Likelihood:                 86.979
# No. Observations:                  50   AIC:                            -166.0
# Df Residuals:                      46   BIC:                            -158.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0929      0.048     -1.921      0.061      -0.190       0.004
# GNI         3.977e-07   4.21e-07      0.944      0.350    -4.5e-07    1.25e-06
# Internet       0.0010      0.000      2.384      0.021       0.000       0.002
# English        0.0049      0.001      4.682      0.000       0.003       0.007
# ==============================================================================
# Omnibus:                       13.931   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.443
# Skew:                          -1.104   Prob(JB):                     0.000443
# Kurtosis:                       4.593   Cond. No.                     2.65e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# pr_editions ~ GNI+Internet+English
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            pr_editions   R-squared:                       0.677
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     32.07
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           2.43e-11
# Time:                        10:32:28   Log-Likelihood:                 122.42
# No. Observations:                  50   AIC:                            -236.8
# Df Residuals:                      46   BIC:                            -229.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0410      0.024     -1.724      0.091      -0.089       0.007
# GNI         3.234e-07   2.07e-07      1.559      0.126    -9.4e-08    7.41e-07
# Internet       0.0004      0.000      2.081      0.043    1.35e-05       0.001
# English        0.0019      0.001      3.789      0.000       0.001       0.003
# ==============================================================================
# Omnibus:                        5.195   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.074   Jarque-Bera (JB):                4.206
# Skew:                          -0.683   Prob(JB):                        0.122
# Kurtosis:                       3.387   Cond. No.                     2.65e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# +++++ END BASELINE +++++

# %%
# M1 models
# Specify the models
m1_formulas = list()
for dv in dvs: 
    form = dv + " ~ "
    form += '+'.join(m1_ivs)

    m1_formulas.append(form)

# Fit the models
m1_results = dict()
for form in m1_formulas:
    assert(isinstance(form, str))
    m1_model = smf.ols(form, data=df_so)
    
    m1_results[form] = m1_model

print("All M1 models:")
# Print summary of models
for form,model in m1_results.items():
    print(form)
    print(model.fit().summary())
    print("\n")

print("+++++ END M1 +++++")
# Out:
# All M1 models:
# pr_questions ~ GNI+Internet+English+IDV
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           pr_questions   R-squared:                       0.547
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     13.58
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           2.43e-07
# Time:                        10:33:26   Log-Likelihood:                 79.065
# No. Observations:                  50   AIC:                            -148.1
# Df Residuals:                      45   BIC:                            -138.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2657      0.064      4.183      0.000       0.138       0.394
# GNI        -2.537e-07   5.21e-07     -0.487      0.629    -1.3e-06    7.96e-07
# Internet       0.0004      0.000      0.776      0.442      -0.001       0.001
# English        0.0037      0.001      2.554      0.014       0.001       0.007
# IDV            0.0009      0.001      1.744      0.088      -0.000       0.002
# ==============================================================================
# Omnibus:                        1.408   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.495   Jarque-Bera (JB):                0.656
# Skew:                          -0.181   Prob(JB):                        0.720
# Kurtosis:                       3.428   Cond. No.                     2.94e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.94e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# pr_answers ~ GNI+Internet+English+IDV
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             pr_answers   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     18.22
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           5.80e-09
# Time:                        10:33:26   Log-Likelihood:                 73.481
# No. Observations:                  50   AIC:                            -137.0
# Df Residuals:                      45   BIC:                            -127.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2440      0.071      3.435      0.001       0.101       0.387
# GNI         2.052e-07   5.83e-07      0.352      0.726   -9.68e-07    1.38e-06
# Internet       0.0007      0.001      1.249      0.218      -0.000       0.002
# English        0.0029      0.002      1.793      0.080      -0.000       0.006
# IDV            0.0013      0.001      2.231      0.031       0.000       0.003
# ==============================================================================
# Omnibus:                        3.615   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.164   Jarque-Bera (JB):                2.539
# Skew:                          -0.465   Prob(JB):                        0.281
# Kurtosis:                       3.596   Cond. No.                     2.94e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.94e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# pr_comments ~ GNI+Internet+English+IDV
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            pr_comments   R-squared:                       0.746
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     33.01
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           7.33e-13
# Time:                        10:33:27   Log-Likelihood:                 90.028
# No. Observations:                  50   AIC:                            -170.1
# Df Residuals:                      45   BIC:                            -160.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0396      0.051     -0.776      0.442      -0.142       0.063
# GNI         1.072e-07   4.18e-07      0.256      0.799   -7.36e-07     9.5e-07
# Internet       0.0008      0.000      2.059      0.045    1.77e-05       0.002
# English        0.0034      0.001      2.869      0.006       0.001       0.006
# IDV            0.0010      0.000      2.416      0.020       0.000       0.002
# ==============================================================================
# Omnibus:                        2.945   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.229   Jarque-Bera (JB):                1.998
# Skew:                          -0.446   Prob(JB):                        0.368
# Kurtosis:                       3.404   Cond. No.                     2.94e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.94e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# pr_editions ~ GNI+Internet+English+IDV
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            pr_editions   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     35.82
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           1.87e-13
# Time:                        10:33:27   Log-Likelihood:                 129.99
# No. Observations:                  50   AIC:                            -250.0
# Df Residuals:                      45   BIC:                            -240.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0014      0.023     -0.063      0.950      -0.048       0.045
# GNI         1.078e-07   1.88e-07      0.573      0.570   -2.71e-07    4.87e-07
# Internet       0.0003      0.000      1.682      0.099   -5.82e-05       0.001
# English        0.0008      0.001      1.554      0.127      -0.000       0.002
# IDV            0.0008      0.000      3.987      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                        0.134   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.935   Jarque-Bera (JB):                0.342
# Skew:                           0.001   Prob(JB):                        0.843
# Kurtosis:                       2.595   Cond. No.                     2.94e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.94e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# +++++ END M1 +++++

# %%
# M2 models
# Specify the models
m2_formulas = list()
for dv in dvs: 
    form = dv + " ~ "
    form += '+'.join(m2_ivs)

    m2_formulas.append(form)

# Fit the models
m2_results = dict()
for form in m2_formulas:
    assert(isinstance(form, str))
    m2_model = smf.ols(form, data=df_so)
    
    m2_results[form] = m2_model

print("All M2 models:")
# Print summary of models
for form,model in m2_results.items():
    print(form)
    print(model.fit().summary())
    print("\n")

print("+++++ END M2 +++++")
# Out:
# All M2 models:
# pr_questions ~ GNI+Internet+English+WVS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           pr_questions   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     12.53
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           6.25e-07
# Time:                        10:47:06   Log-Likelihood:                 77.979
# No. Observations:                  50   AIC:                            -146.0
# Df Residuals:                      45   BIC:                            -136.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2376      0.062      3.845      0.000       0.113       0.362
# GNI        -3.563e-07   6.27e-07     -0.569      0.573   -1.62e-06    9.06e-07
# Internet       0.0006      0.000      1.240      0.221      -0.000       0.002
# English        0.0047      0.001      3.614      0.001       0.002       0.007
# WVS            0.0106      0.011      0.999      0.323      -0.011       0.032
# ==============================================================================
# Omnibus:                        1.638   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.441   Jarque-Bera (JB):                0.841
# Skew:                          -0.227   Prob(JB):                        0.657
# Kurtosis:                       3.445   Cond. No.                     2.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# pr_answers ~ GNI+Internet+English+WVS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             pr_answers   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.576
# Method:                 Least Squares   F-statistic:                     17.61
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           9.14e-09
# Time:                        10:47:06   Log-Likelihood:                 72.963
# No. Observations:                  50   AIC:                            -135.9
# Df Residuals:                      45   BIC:                            -126.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2189      0.068      3.206      0.002       0.081       0.357
# GNI        -2.215e-07   6.93e-07     -0.320      0.751   -1.62e-06    1.17e-06
# Internet       0.0011      0.001      1.995      0.052   -1.07e-05       0.002
# English        0.0041      0.001      2.825      0.007       0.001       0.007
# WVS            0.0233      0.012      1.988      0.053      -0.000       0.047
# ==============================================================================
# Omnibus:                        6.073   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.048   Jarque-Bera (JB):                4.974
# Skew:                          -0.714   Prob(JB):                       0.0832
# Kurtosis:                       3.592   Cond. No.                     2.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# pr_comments ~ GNI+Internet+English+WVS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            pr_comments   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     28.38
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           8.50e-12
# Time:                        10:47:06   Log-Likelihood:                 87.262
# No. Observations:                  50   AIC:                            -164.5
# Df Residuals:                      45   BIC:                            -155.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0811      0.051     -1.580      0.121      -0.184       0.022
# GNI          1.81e-07    5.2e-07      0.348      0.730   -8.67e-07    1.23e-06
# Internet       0.0010      0.000      2.466      0.018       0.000       0.002
# English        0.0047      0.001      4.287      0.000       0.002       0.007
# WVS            0.0063      0.009      0.717      0.477      -0.011       0.024
# ==============================================================================
# Omnibus:                        9.461   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                8.815
# Skew:                          -0.893   Prob(JB):                       0.0122
# Kurtosis:                       4.020   Cond. No.                     2.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# pr_editions ~ GNI+Internet+English+WVS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            pr_editions   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     24.11
# Date:                Mon, 25 Oct 2021   Prob (F-statistic):           1.05e-10
# Time:                        10:47:06   Log-Likelihood:                 122.84
# No. Observations:                  50   AIC:                            -235.7
# Df Residuals:                      45   BIC:                            -226.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0340      0.025     -1.351      0.184      -0.085       0.017
# GNI         1.949e-07   2.55e-07      0.763      0.449    -3.2e-07     7.1e-07
# Internet       0.0004      0.000      2.205      0.033    3.89e-05       0.001
# English        0.0018      0.001      3.402      0.001       0.001       0.003
# WVS            0.0037      0.004      0.865      0.391      -0.005       0.012
# ==============================================================================
# Omnibus:                        2.383   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.304   Jarque-Bera (JB):                1.879
# Skew:                          -0.475   Prob(JB):                        0.391
# Kurtosis:                       3.020   Cond. No.                     2.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# +++++ END M2 +++++
